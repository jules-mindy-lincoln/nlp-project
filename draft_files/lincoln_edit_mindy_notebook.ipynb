# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
from nltk import trigrams
from nltk import bigrams
from collections import Counter

import pandas as pd
import numpy as np
import os
import time
import csv
import json
from typing import Dict, List, Optional, Union, cast
import requests
import prepare

import seaborn as sns
import matplotlib as plt

from bs4 import BeautifulSoup

df = prepare.wrangle_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257 entries, 0 to 390
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   repo             257 non-null    object
#  1   language         257 non-null    object
#  2   readme_contents  257 non-null    object
#  3   stemmed          257 non-null    object
#  4   lemmatized       257 non-null    object
# dtypes: object(5)
# memory usage: 12.0+ KB

# %% [markdown]
# #### prepare notes-
# - talk about handling nulls, decision to drop langs with < 5 records, and JN
# - talk about steps to get lemmatized column

# %%
df.head()
# Out:
#                                    repo    language  \
# 0  dreamingechoes/awesome-mental-health        HTML
# 1                          Flaque/quirk  TypeScript
# 4                  sepandhaghighi/nafas      Python
# 5                youarerad/youareradweb  TypeScript
# 7            OSMIHelp/osmi-survey-graph         PHP
#
#                                      readme_contents  \
# 0  \n<p align="center"><img src="./media/logo.png...
# 1  🚧🚧🚧\n\n**Quirk is no longer being maintained.*...
# 4  <div align="center">\n<img src="https://github...
# 5  <div align="center"><img src="https://res.clou...
# 7  # 2016 OSMI Survey Graph\n\n## Installing and ...
#
#                                              stemmed  \
# 0  aboutsparkl curat list awesom articl websit re...
# 1  quirk longer maintainedquirk start littl thing...
# 4  nafa &#9; tabl content overview instal usag is...
# 5  welcom rise disord ' websit repow nonprofit co...
# 7  2016 osmi survey graph instal run copi envexam...
#
#                                           lemmatized
# 0  aboutsparkles curated list awesome article web...
# 1  quirk longer maintainedquirk started little th...
# 4  nafas &#9; table content overview installation...
# 5  welcome rise disorder ' website repowe nonprof...
# 7  2016 osmi survey graph installing running copy...

# %%
df.language.nunique()
# Out:
# 12

# %%
df.language.value_counts()
# Out:
# JavaScript    62
# HTML          44
# Python        41
# TypeScript    24
# Java          22
# Dart          14
# R             13
# CSS           12
# Swift          9
# Vue            6
# PHP            5
# C++            5
# Name: language, dtype: int64

# %% [markdown]
# #### show counts and percentage of languages
#
# - put this in function

# %%
langs = pd.concat([df.language.value_counts(),
                    df.language.value_counts(normalize=True)], axis=1)
langs.columns = ['counts', 'percent']
langs
# Out:
#             counts   percent
# JavaScript      62  0.241245
# HTML            44  0.171206
# Python          41  0.159533
# TypeScript      24  0.093385
# Java            22  0.085603
# Dart            14  0.054475
# R               13  0.050584
# CSS             12  0.046693
# Swift            9  0.035019
# Vue              6  0.023346
# PHP              5  0.019455
# C++              5  0.019455

# %%
ADDITIONAL = ['The', 'I', 'This','Mental','Health','mental','health']
def clean(readme_contents):
    'A simple function to cleanup text data'
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english') + ADDITIONAL
    text = (unicodedata.normalize('NFKD', readme_contents)
             .encode('ascii', 'ignore')
             .decode('utf-8', 'ignore')
             .lower())
#     words = re.sub(r"[^a-z0-9'\s]", '', readme_contents).split()
    words = re.sub(r'[^\w\s]', '', text).split()
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
JavaScript_words = clean(' '.join(df[df.language == 'JavaScript'].readme_contents))
HTML_words = clean(' '.join(df[df.language == 'HTML'].readme_contents))
Python_words = clean(' '.join(df[df.language == 'Python'].readme_contents))
TypeScript_words = clean(' '.join(df[df.language == 'TypeScript'].readme_contents))
Java_words = clean(' '.join(df[df.language == 'Java'].readme_contents))
Dart_words = clean(' '.join(df[df.language == 'Dart'].readme_contents))
CSS_words = clean(' '.join(df[df.language == 'CSS'].readme_contents))
R_words = clean(' '.join(df[df.language == 'R'].readme_contents))
Swift_words = clean(' '.join(df[df.language == 'Swift'].readme_contents))
Vue_words = clean(' '.join(df[df.language == 'Vue'].readme_contents))
PHP_words = clean(' '.join(df[df.language == 'PHP'].readme_contents))
C_words = clean(' '.join(df[df.language == 'C++'].readme_contents))
all_words = clean(' '.join(df.readme_contents))

# %%
df['total_words'] = df['lemmatized'].str.split().str.len()

# %%
df = df[df.total_words > 5]

# %%
df
# Out:
#                                         repo    language  \
# 0       dreamingechoes/awesome-mental-health        HTML
# 1                               Flaque/quirk  TypeScript
# 4                       sepandhaghighi/nafas      Python
# 5                     youarerad/youareradweb  TypeScript
# 7                 OSMIHelp/osmi-survey-graph         PHP
# ..                                       ...         ...
# 380             EdwardRees/Self-Care-Project  TypeScript
# 384   sumantchirde/Mental-Health-NLP-project      Python
# 385                        Levodex/RipplerPy  JavaScript
# 387                    acfromspace/soulstone        HTML
# 390  brunomontezano/gender-and-mental-health           R
#
#                                        readme_contents  \
# 0    \n<p align="center"><img src="./media/logo.png...
# 1    🚧🚧🚧\n\n**Quirk is no longer being maintained.*...
# 4    <div align="center">\n<img src="https://github...
# 5    <div align="center"><img src="https://res.clou...
# 7    # 2016 OSMI Survey Graph\n\n## Installing and ...
# ..                                                 ...
# 380  # Self Care Project\n\nWhat used to be a Menta...
# 384  #  Mental health assessment by NLP and ML usin...
# 385  ## About\n* \n* (Read github/bitbucket descrip...
# 387  <!-- HEADING -->\n\n<h1 align="center">soulsto...
# 390  # Prevalência de transtornos mentais entre gên...
#
#                                                stemmed  \
# 0    aboutsparkl curat list awesom articl websit re...
# 1    quirk longer maintainedquirk start littl thing...
# 4    nafa &#9; tabl content overview instal usag is...
# 5    welcom rise disord ' websit repow nonprofit co...
# 7    2016 osmi survey graph instal run copi envexam...
# ..                                                 ...
# 380  self care projectwhat use mental health projec...
# 384  mental health assess nlp ml use tensorflownowa...
# 385  read githubbitbucket descript copyright notice...
# 387  soulstoneperson reflect thought one ' selfswee...
# 390  prevalencia de transtorno mentai entr genero p...
#
#                                             lemmatized  total_words
# 0    aboutsparkles curated list awesome article web...         1140
# 1    quirk longer maintainedquirk started little th...         1061
# 4    nafas &#9; table content overview installation...          351
# 5    welcome rise disorder ' website repowe nonprof...           83
# 7    2016 osmi survey graph installing running copy...          419
# ..                                                 ...          ...
# 380  self care projectwhat used mental health proje...           49
# 384  mental health assessment nlp ml using tensorfl...           88
# 385  read githubbitbucket description copyright not...          155
# 387  soulstonepersonal reflection thought one ' sel...           15
# 390  prevalencia de transtornos mentais entre gener...          101
#
# [238 rows x 6 columns]

# %%
df.language.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.total_words.groupby(df.language).mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='language'>

# %%
conditions = [(df.total_words > 183),
              (df.total_words >= 66) & (df.total_words <= 183),
              (df.total_words < 66)]
choices = ['high_count', 'med_count', 'low_count']

df['count_bin'] = np.select(conditions, choices)

# %%
df_plot = df.groupby(['language', 'count_bin']).size().reset_index().pivot(columns='count_bin', index='language', values=0)

# %%
df_plot.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='language'>

# %%
df
# Out:
#                                         repo    language  \
# 0       dreamingechoes/awesome-mental-health        HTML
# 1                               Flaque/quirk  TypeScript
# 4                       sepandhaghighi/nafas      Python
# 5                     youarerad/youareradweb  TypeScript
# 7                 OSMIHelp/osmi-survey-graph         PHP
# ..                                       ...         ...
# 380             EdwardRees/Self-Care-Project  TypeScript
# 384   sumantchirde/Mental-Health-NLP-project      Python
# 385                        Levodex/RipplerPy  JavaScript
# 387                    acfromspace/soulstone        HTML
# 390  brunomontezano/gender-and-mental-health           R
#
#                                        readme_contents  \
# 0    \n<p align="center"><img src="./media/logo.png...
# 1    🚧🚧🚧\n\n**Quirk is no longer being maintained.*...
# 4    <div align="center">\n<img src="https://github...
# 5    <div align="center"><img src="https://res.clou...
# 7    # 2016 OSMI Survey Graph\n\n## Installing and ...
# ..                                                 ...
# 380  # Self Care Project\n\nWhat used to be a Menta...
# 384  #  Mental health assessment by NLP and ML usin...
# 385  ## About\n* \n* (Read github/bitbucket descrip...
# 387  <!-- HEADING -->\n\n<h1 align="center">soulsto...
# 390  # Prevalência de transtornos mentais entre gên...
#
#                                                stemmed  \
# 0    aboutsparkl curat list awesom articl websit re...
# 1    quirk longer maintainedquirk start littl thing...
# 4    nafa &#9; tabl content overview instal usag is...
# 5    welcom rise disord ' websit repow nonprofit co...
# 7    2016 osmi survey graph instal run copi envexam...
# ..                                                 ...
# 380  self care projectwhat use mental health projec...
# 384  mental health assess nlp ml use tensorflownowa...
# 385  read githubbitbucket descript copyright notice...
# 387  soulstoneperson reflect thought one ' selfswee...
# 390  prevalencia de transtorno mentai entr genero p...
#
#                                             lemmatized  total_words  \
# 0    aboutsparkles curated list awesome article web...         1140
# 1    quirk longer maintainedquirk started little th...         1061
# 4    nafas &#9; table content overview installation...          351
# 5    welcome rise disorder ' website repowe nonprof...           83
# 7    2016 osmi survey graph installing running copy...          419
# ..                                                 ...          ...
# 380  self care projectwhat used mental health proje...           49
# 384  mental health assessment nlp ml using tensorfl...           88
# 385  read githubbitbucket description copyright not...          155
# 387  soulstonepersonal reflection thought one ' sel...           15
# 390  prevalencia de transtornos mentais entre gener...          101
#
#       count_bin
# 0    high_count
# 1    high_count
# 4    high_count
# 5     med_count
# 7    high_count
# ..          ...
# 380   low_count
# 384   med_count
# 385   med_count
# 387   low_count
# 390   med_count
#
# [238 rows x 7 columns]

# %%
JavaScript_freq = pd.Series(JavaScript_words).value_counts()
HTML_freq = pd.Series(HTML_words).value_counts()
Python_freq = pd.Series(Python_words).value_counts()
TypeScript_freq = pd.Series(TypeScript_words).value_counts()
Java_freq = pd.Series(Java_words).value_counts()
Dart_freq = pd.Series(Dart_words).value_counts()
CSS_freq = pd.Series(CSS_words).value_counts()
R_freq = pd.Series(R_words).value_counts()
Swift_freq = pd.Series(Swift_words).value_counts()
Vue_freq = pd.Series(Vue_words).value_counts()
PHP_freq = pd.Series(PHP_words).value_counts()
C_freq = pd.Series(C_words).value_counts()
all_freq = pd.Series(all_words).value_counts()

# %%
word_counts = (pd.concat([all_freq, JavaScript_freq, HTML_freq, Python_freq, TypeScript_freq,
                    Java_freq, Dart_freq, CSS_freq, R_freq, Swift_freq, Vue_freq, PHP_freq, C_freq], axis=1, sort=True)
                .set_axis(['all', 'JavaScript', 'HTML', 'Python', 'TypeScript', 'Java', 'Dart', 'CSS', 'R', 'Swift', 'Vue', 'PHP', 'C++'], axis=1, inplace=False)
                .fillna(0)
                .apply(lambda s: s.astype(int)))

word_counts.head()
# Out:
#        all  JavaScript  HTML  Python  TypeScript  Java  Dart  CSS  R  Swift  \
# 0       35          10    16       0           8     0     0    0  0      0
# 000      2           0     1       0           0     0     1    0  0      0
# 0000     1           0     1       0           0     0     0    0  0      0
# 00000    2           0     2       0           0     0     0    0  0      0
# 0001    10           0     9       1           0     0     0    0  0      0
#
#        Vue  PHP  C++
# 0        0    1    0
# 000      0    0    0
# 0000     0    0    0
# 00000    0    0    0
# 0001     0    0    0

# %%
word_counts.sort_values(by='all', ascending=False).head(20)
# Out:
#          all  JavaScript  HTML  Python  TypeScript  Java  Dart  CSS   R  \
# user     478          98   197      34          26    67    26    2   0
# project  348          70    89      34          42    35    33   20   9
# page     315          69   193       2          19    10     3    8   0
# app      293          83    26       8          57    34    46    4   1
# help     264          38    98      30          36     8    28    8   2
# data     254          39    46      79          16    22    14    0  20
# img      245          36    51      35          17    32    37   20   1
# br       236          48   122      11          10    13    10    2   0
# 1        228          41   112      19          17    10    12    6   1
# use      219          58    60      30          17    13     8   10   1
# run      218          73    21      37          19     7     4   22   7
# using    214          54    39      50           7    25     8    6   7
# people   206          29    81      12          42     4    15    9   1
# used     192          37   101      22           8     5     2    6   4
# website  169          40   103       1           9     1     2    9   1
# install  168          43    12      50          22     4     2    6   6
# file     166          35    54      38           7     9     0    4   4
# time     165          32    60      24          12    19     5    3   0
# 2        163          35    54      19          18     9    11    6   2
# want     161          18    86       8          16     9     8    5   0
#
#          Swift  Vue  PHP  C++
# user        18    3    4    3
# project      3    3    4    6
# page         3    3    2    3
# app         28    4    1    1
# help         9    2    0    5
# data         5    2    5    6
# img          9    5    0    2
# br           0   11    6    3
# 1            4    3    0    3
# use          3    1    4   14
# run          2   14   10    2
# using        6    2    4    6
# people       8    0    2    3
# used         3    1    0    3
# website      0    2    1    0
# install      3    6    5    9
# file         2    5    4    4
# time         7    0    1    2
# 2            4    2    0    3
# want         4    0    2    5

# %%
word_counts.sort_values(by='all', ascending=False).head(20)
# Out:
#          all  JavaScript  HTML  Python  TypeScript  Java  Dart  CSS   R  \
# user     478          98   197      34          26    67    26    2   0
# project  348          70    89      34          42    35    33   20   9
# page     315          69   193       2          19    10     3    8   0
# app      293          83    26       8          57    34    46    4   1
# help     264          38    98      30          36     8    28    8   2
# data     254          39    46      79          16    22    14    0  20
# img      245          36    51      35          17    32    37   20   1
# br       236          48   122      11          10    13    10    2   0
# 1        228          41   112      19          17    10    12    6   1
# use      219          58    60      30          17    13     8   10   1
# run      218          73    21      37          19     7     4   22   7
# using    214          54    39      50           7    25     8    6   7
# people   206          29    81      12          42     4    15    9   1
# used     192          37   101      22           8     5     2    6   4
# website  169          40   103       1           9     1     2    9   1
# install  168          43    12      50          22     4     2    6   6
# file     166          35    54      38           7     9     0    4   4
# time     165          32    60      24          12    19     5    3   0
# 2        163          35    54      19          18     9    11    6   2
# want     161          18    86       8          16     9     8    5   0
#
#          Swift  Vue  PHP  C++
# user        18    3    4    3
# project      3    3    4    6
# page         3    3    2    3
# app         28    4    1    1
# help         9    2    0    5
# data         5    2    5    6
# img          9    5    0    2
# br           0   11    6    3
# 1            4    3    0    3
# use          3    1    4   14
# run          2   14   10    2
# using        6    2    4    6
# people       8    0    2    3
# used         3    1    0    3
# website      0    2    1    0
# install      3    6    5    9
# file         2    5    4    4
# time         7    0    1    2
# 2            4    2    0    3
# want         4    0    2    5

# %%
most_freq_155 = word_counts[word_counts['all'] > 155] 
most_freq_155 = most_freq_155[most_freq_155['all'] < 180]
most_freq_180 = word_counts[word_counts['all'] >= 180]
most_freq_180 = most_freq_180[most_freq_180['all'] < 220]
most_freq = word_counts[word_counts['all'] >= 220]

# %%
most_freq.head()
# Out:
#       all  JavaScript  HTML  Python  TypeScript  Java  Dart  CSS   R  Swift  \
# 1     228          41   112      19          17    10    12    6   1      4
# app   293          83    26       8          57    34    46    4   1     28
# br    236          48   122      11          10    13    10    2   0      0
# data  254          39    46      79          16    22    14    0  20      5
# help  264          38    98      30          36     8    28    8   2      9
#
#       Vue  PHP  C++
# 1       3    0    3
# app     4    1    1
# br     11    6    3
# data    2    5    6
# help    2    0    5

# %%
word_perc = pd.DataFrame()
for col in most_freq.columns:
    word_perc = word_perc.append(most_freq[col].sort_values(ascending=False)/most_freq[col].sum())

word_perc_155 = pd.DataFrame()
for col in most_freq_155.columns:
    word_perc_155 = word_perc_155.append(most_freq_155[col].sort_values(ascending=False)/most_freq_155[col].sum())
    
word_perc_180 = pd.DataFrame()
for col in most_freq_180.columns:
    word_perc_180 = word_perc_180.append(most_freq_180[col].sort_values(ascending=False)/most_freq_180[col].sum())

# %%
word_perc
# Out:
#                 user   project      page       app      help      data  \
# all         0.179632  0.130778  0.118377  0.110109  0.099211  0.095453
# JavaScript  0.187739  0.134100  0.132184  0.159004  0.072797  0.074713
# HTML        0.210921  0.095289  0.206638  0.027837  0.104925  0.049251
# Python      0.134921  0.134921  0.007937  0.031746  0.119048  0.313492
# TypeScript  0.108333  0.175000  0.079167  0.237500  0.150000  0.066667
# Java        0.290043  0.151515  0.043290  0.147186  0.034632  0.095238
# Dart        0.124402  0.157895  0.014354  0.220096  0.133971  0.066986
# CSS         0.028571  0.285714  0.114286  0.057143  0.114286  0.000000
# R           0.000000  0.264706  0.000000  0.029412  0.058824  0.588235
# Swift       0.227848  0.037975  0.037975  0.354430  0.113924  0.063291
# Vue         0.083333  0.083333  0.083333  0.111111  0.055556  0.055556
# PHP         0.181818  0.181818  0.090909  0.045455  0.000000  0.227273
# C++         0.093750  0.187500  0.093750  0.031250  0.156250  0.187500
#
#                  img        br         1
# all         0.092071  0.088688  0.085682
# JavaScript  0.068966  0.091954  0.078544
# HTML        0.054604  0.130621  0.119914
# Python      0.138889  0.043651  0.075397
# TypeScript  0.070833  0.041667  0.070833
# Java        0.138528  0.056277  0.043290
# Dart        0.177033  0.047847  0.057416
# CSS         0.285714  0.028571  0.085714
# R           0.029412  0.000000  0.029412
# Swift       0.113924  0.000000  0.050633
# Vue         0.138889  0.305556  0.083333
# PHP         0.000000  0.272727  0.000000
# C++         0.062500  0.093750  0.093750

# %%
plt.rcParams["figure.figsize"] = (20,10)
most_freq.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (20,10)
word_perc.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
word_perc_T = word_perc.T
word_perc_155_T = word_perc_155.T
word_perc_180_T = word_perc_180.T

# %% [markdown]
# to look at similarities, we simple look at bars w similar heights. That will show they have a similar distribution of that specific word

# %%
plt.rcParams["figure.figsize"] = (20,8)
word_perc_T.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.rcParams["figure.figsize"] = (20,8)
word_perc_155_T.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
word_perc_T
# Out:
#               all  JavaScript      HTML    Python  TypeScript      Java  \
# user     0.179632    0.187739  0.210921  0.134921    0.108333  0.290043
# project  0.130778    0.134100  0.095289  0.134921    0.175000  0.151515
# page     0.118377    0.132184  0.206638  0.007937    0.079167  0.043290
# app      0.110109    0.159004  0.027837  0.031746    0.237500  0.147186
# help     0.099211    0.072797  0.104925  0.119048    0.150000  0.034632
# data     0.095453    0.074713  0.049251  0.313492    0.066667  0.095238
# img      0.092071    0.068966  0.054604  0.138889    0.070833  0.138528
# br       0.088688    0.091954  0.130621  0.043651    0.041667  0.056277
# 1        0.085682    0.078544  0.119914  0.075397    0.070833  0.043290
#
#              Dart       CSS         R     Swift       Vue       PHP      C++
# user     0.124402  0.028571  0.000000  0.227848  0.083333  0.181818  0.09375
# project  0.157895  0.285714  0.264706  0.037975  0.083333  0.181818  0.18750
# page     0.014354  0.114286  0.000000  0.037975  0.083333  0.090909  0.09375
# app      0.220096  0.057143  0.029412  0.354430  0.111111  0.045455  0.03125
# help     0.133971  0.114286  0.058824  0.113924  0.055556  0.000000  0.15625
# data     0.066986  0.000000  0.588235  0.063291  0.055556  0.227273  0.18750
# img      0.177033  0.285714  0.029412  0.113924  0.138889  0.000000  0.06250
# br       0.047847  0.028571  0.000000  0.000000  0.305556  0.272727  0.09375
# 1        0.057416  0.085714  0.029412  0.050633  0.083333  0.000000  0.09375

# %%
plt.rcParams["figure.figsize"] = (20,8)
word_perc_180_T.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
langs = pd.concat([df.language.value_counts(),
                    df.language.value_counts(normalize=True)], axis=1)
langs.columns = ['counts', 'percent']
langs
# Out:
#             counts   percent
# JavaScript      58  0.243697
# HTML            42  0.176471
# Python          39  0.163866
# TypeScript      23  0.096639
# Java            18  0.075630
# R               13  0.054622
# Dart            12  0.050420
# CSS             10  0.042017
# Swift            8  0.033613
# Vue              6  0.025210
# PHP              5  0.021008
# C++              4  0.016807

# %%
df
# Out:
#                                         repo    language  \
# 0       dreamingechoes/awesome-mental-health        HTML
# 1                               Flaque/quirk  TypeScript
# 4                       sepandhaghighi/nafas      Python
# 5                     youarerad/youareradweb  TypeScript
# 7                 OSMIHelp/osmi-survey-graph         PHP
# ..                                       ...         ...
# 380             EdwardRees/Self-Care-Project  TypeScript
# 384   sumantchirde/Mental-Health-NLP-project      Python
# 385                        Levodex/RipplerPy  JavaScript
# 387                    acfromspace/soulstone        HTML
# 390  brunomontezano/gender-and-mental-health           R
#
#                                        readme_contents  \
# 0    \n<p align="center"><img src="./media/logo.png...
# 1    🚧🚧🚧\n\n**Quirk is no longer being maintained.*...
# 4    <div align="center">\n<img src="https://github...
# 5    <div align="center"><img src="https://res.clou...
# 7    # 2016 OSMI Survey Graph\n\n## Installing and ...
# ..                                                 ...
# 380  # Self Care Project\n\nWhat used to be a Menta...
# 384  #  Mental health assessment by NLP and ML usin...
# 385  ## About\n* \n* (Read github/bitbucket descrip...
# 387  <!-- HEADING -->\n\n<h1 align="center">soulsto...
# 390  # Prevalência de transtornos mentais entre gên...
#
#                                                stemmed  \
# 0    aboutsparkl curat list awesom articl websit re...
# 1    quirk longer maintainedquirk start littl thing...
# 4    nafa &#9; tabl content overview instal usag is...
# 5    welcom rise disord ' websit repow nonprofit co...
# 7    2016 osmi survey graph instal run copi envexam...
# ..                                                 ...
# 380  self care projectwhat use mental health projec...
# 384  mental health assess nlp ml use tensorflownowa...
# 385  read githubbitbucket descript copyright notice...
# 387  soulstoneperson reflect thought one ' selfswee...
# 390  prevalencia de transtorno mentai entr genero p...
#
#                                             lemmatized  total_words  \
# 0    aboutsparkles curated list awesome article web...         1140
# 1    quirk longer maintainedquirk started little th...         1061
# 4    nafas &#9; table content overview installation...          351
# 5    welcome rise disorder ' website repowe nonprof...           83
# 7    2016 osmi survey graph installing running copy...          419
# ..                                                 ...          ...
# 380  self care projectwhat used mental health proje...           49
# 384  mental health assessment nlp ml using tensorfl...           88
# 385  read githubbitbucket description copyright not...          155
# 387  soulstonepersonal reflection thought one ' sel...           15
# 390  prevalencia de transtornos mentais entre gener...          101
#
#       count_bin
# 0    high_count
# 1    high_count
# 4    high_count
# 5     med_count
# 7    high_count
# ..          ...
# 380   low_count
# 384   med_count
# 385   med_count
# 387   low_count
# 390   med_count
#
# [238 rows x 7 columns]

# %%
trigrams = [x for x in df['lemmatized'] for x in trigrams(x.split())]
trigrams
# Out:
# [('aboutsparkles', 'curated', 'list'),
#  ('curated', 'list', 'awesome'),
#  ('list', 'awesome', 'article'),
#  ('awesome', 'article', 'website'),
#  ('article', 'website', 'resource'),
#  ('website', 'resource', 'mental'),
#  ('resource', 'mental', 'health'),
#  ('mental', 'health', 'software'),
#  ('health', 'software', 'industry'),
#  ('software', 'industry', 'sparklesmental'),
#  ('industry', 'sparklesmental', 'health'),
#  ('sparklesmental', 'health', 'level'),
#  ('health', 'level', 'psychological'),
#  ('level', 'psychological', 'wellbeing'),
#  ('psychological', 'wellbeing', 'absence'),
#  ('wellbeing', 'absence', 'mental'),
#  ('absence', 'mental', 'illness'),
#  ('mental', 'illness', "'"),
#  ('illness', "'", 'psychological'),
#  ("'", 'psychological', 'state'),
#  ('psychological', 'state', 'someone'),
#  ('state', 'someone', 'functioning'),
#  ('someone', 'functioning', 'satisfactory'),
#  ('functioning', 'satisfactory', 'level'),
#  ('satisfactory', 'level', 'emotional'),
#  ('level', 'emotional', 'behavioural'),
#  ('emotional', 'behavioural', 'adjustmentit'),
#  ('behavioural', 'adjustmentit', 'includes'),
#  ('adjustmentit', 'includes', 'subjective'),
#  ('includes', 'subjective', 'wellbeing'),
#  ('subjective', 'wellbeing', 'perceived'),
#  ('wellbeing', 'perceived', 'selfefficacy'),
#  ('perceived', 'selfefficacy', 'autonomy'),
#  ('selfefficacy', 'autonomy', 'competence'),
#  ('autonomy', 'competence', 'intergenerational'),
#  ('competence', 'intergenerational', 'dependence'),
#  ('intergenerational', 'dependence', 'selfactualization'),
#  ('dependence', 'selfactualization', 'one'),
#  ('selfactualization', 'one', "'"),
#  ('one', "'", 'intellectual'),
#  ("'", 'intellectual', 'emotional'),
#  ('intellectual', 'emotional', 'potential'),
#  ('emotional', 'potential', 'among'),
#  ('potential', 'among', 'others'),
#  ('among', 'others', 'list'),
#  ('others', 'list', 'compiles'),
#  ('list', 'compiles', 'several'),
#  ('compiles', 'several', 'selfhelp'),
#  ('several', 'selfhelp', 'resource'),
#  ('selfhelp', 'resource', "'"),
#  ('resource', "'", 'personally'),
#  ("'", 'personally', 'found'),
#  ('personally', 'found', 'useful'),
#  ('found', 'useful', 'range'),
#  ('useful', 'range', 'mental'),
#  ('range', 'mental', 'health'),
#  ('mental', 'health', 'problem'),
#  ('health', 'problem', 'way'),
#  ('problem', 'way', 'replacement'),
#  ('way', 'replacement', 'professional'),
#  ('replacement', 'professional', 'help'),
#  ('professional', 'help', 'psychotherapy'),
#  ('help', 'psychotherapy', 'pharmacotherapy'),
#  ('psychotherapy', 'pharmacotherapy', "'"),
#  ('pharmacotherapy', "'", 'expert'),
#  ("'", 'expert', 'even'),
#  ('expert', 'even', 'tool'),
#  ('even', 'tool', 'meant'),
#  ('tool', 'meant', 'aid'),
#  ('meant', 'aid', 'therapy'),
#  ('aid', 'therapy', 'substituteif'),
#  ('therapy', 'substituteif', "'"),
#  ('substituteif', "'", 'crisis'),
#  ("'", 'crisis', 'please'),
#  ('crisis', 'please', 'see'),
#  ('please', 'see', 'resource'),
#  ('see', 'resource', 'country'),
#  ('resource', 'country', 'content'),
#  ('country', 'content', 'applicationsapplications'),
#  ('content', 'applicationsapplications', 'articlesarticles'),
#  ('applicationsapplications', 'articlesarticles', 'booksbooks'),
#  ('articlesarticles', 'booksbooks', 'conferencesconferences'),
#  ('booksbooks', 'conferencesconferences', 'meetupsmeetups'),
#  ('conferencesconferences', 'meetupsmeetups', 'organizationsorganizations'),
#  ('meetupsmeetups', 'organizationsorganizations', 'podcastspodcasts'),
#  ('organizationsorganizations', 'podcastspodcasts', 'talkstalks'),
#  ('podcastspodcasts', 'talkstalks', 'applicationsapplications'),
#  ('talkstalks', 'applicationsapplications', 'help'),
#  ('applicationsapplications', 'help', 'dealing'),
#  ('help', 'dealing', 'anxiety'),
#  ('dealing', 'anxiety', 'depression'),
#  ('anxiety', 'depression', 'mental'),
#  ('depression', 'mental', 'health'),
#  ('mental', 'health', 'problem'),
#  ('health', 'problem', 'moodpath'),
#  ('problem', 'moodpath', 'interactive'),
#  ('moodpath', 'interactive', 'appbased'),
#  ('interactive', 'appbased', 'screening'),
#  ('appbased', 'screening', 'created'),
#  ('screening', 'created', 'recognize'),
#  ('created', 'recognize', 'symptom'),
#  ('recognize', 'symptom', 'depression'),
#  ('symptom', 'depression', 'nyxo'),
#  ('depression', 'nyxo', 'open'),
#  ('nyxo', 'open', 'source'),
#  ('open', 'source', 'sleep'),
#  ('source', 'sleep', 'tracking'),
#  ('sleep', 'tracking', 'sleep'),
#  ('tracking', 'sleep', 'coaching'),
#  ('sleep', 'coaching', 'app'),
#  ('coaching', 'app', 'io'),
#  ('app', 'io', 'android'),
#  ('io', 'android', 'sanvello'),
#  ('android', 'sanvello', 'daily'),
#  ('sanvello', 'daily', 'tool'),
#  ('daily', 'tool', 'stress'),
#  ('tool', 'stress', 'anxiety'),
#  ('stress', 'anxiety', 'depression'),
#  ('anxiety', 'depression', 'alongside'),
#  ('depression', 'alongside', 'supportive'),
#  ('alongside', 'supportive', 'community'),
#  ('supportive', 'community', 'based'),
#  ('community', 'based', 'cognitive'),
#  ('based', 'cognitive', 'behavioral'),
#  ('cognitive', 'behavioral', 'therapy'),
#  ('behavioral', 'therapy', 'mindfulness'),
#  ('therapy', 'mindfulness', 'meditation'),
#  ('mindfulness', 'meditation', 'quirk'),
#  ('meditation', 'quirk', 'gpl'),
#  ('quirk', 'gpl', 'licensed'),
#  ('gpl', 'licensed', 'cognitive'),
#  ('licensed', 'cognitive', 'behavioral'),
#  ('cognitive', 'behavioral', 'therapy'),
#  ('behavioral', 'therapy', 'cbt'),
#  ('therapy', 'cbt', 'app'),
#  ('cbt', 'app', 'io'),
#  ('app', 'io', 'android'),
#  ('io', 'android', 'three'),
#  ('android', 'three', 'good'),
#  ('three', 'good', 'thing'),
#  ('good', 'thing', 'write'),
#  ('thing', 'write', 'three'),
#  ('write', 'three', 'good'),
#  ('three', 'good', 'thing'),
#  ('good', 'thing', 'life'),
#  ('thing', 'life', 'every'),
#  ('life', 'every', 'morning'),
#  ('every', 'morning', 'wake'),
#  ('morning', 'wake', 'time'),
#  ('wake', 'time', 'calculates'),
#  ('time', 'calculates', 'optimal'),
#  ('calculates', 'optimal', 'time'),
#  ('optimal', 'time', 'wake'),
#  ('time', 'wake', 'based'),
#  ('wake', 'based', 'body'),
#  ('based', 'body', "'"),
#  ('body', "'", 'sleep'),
#  ("'", 'sleep', 'cycle'),
#  ('sleep', 'cycle', 'anxious'),
#  ('cycle', 'anxious', 'collection'),
#  ('anxious', 'collection', 'mental'),
#  ('collection', 'mental', 'health'),
#  ('mental', 'health', 'wellness'),
#  ('health', 'wellness', 'apps'),
#  ('wellness', 'apps', 'plus'),
#  ('apps', 'plus', 'resource'),
#  ('plus', 'resource', 'wrabit'),
#  ('resource', 'wrabit', 'build'),
#  ('wrabit', 'build', 'daily'),
#  ('build', 'daily', 'writing'),
#  ('daily', 'writing', 'habit'),
#  ('writing', 'habit', 'contributing'),
#  ('habit', 'contributing', 'mental'),
#  ('contributing', 'mental', 'health'),
#  ('mental', 'health', 'research'),
#  ('health', 'research', 'articlesarticles'),
#  ('research', 'articlesarticles', 'post'),
#  ('articlesarticles', 'post', 'paper'),
#  ('post', 'paper', 'mental'),
#  ('paper', 'mental', 'health'),
#  ('mental', 'health', 'technology'),
#  ('health', 'technology', 'programmer'),
#  ('technology', 'programmer', 'guide'),
#  ('programmer', 'guide', 'stress'),
#  ('guide', 'stress', 'daragh'),
#  ('stress', 'daragh', 'byrne'),
#  ('daragh', 'byrne', 'okay'),
#  ('byrne', 'okay', 'state'),
#  ('okay', 'state', 'mental'),
#  ('state', 'mental', 'health'),
#  ('mental', 'health', 'tech'),
#  ('health', 'tech', '2016'),
#  ('tech', '2016', 'julia'),
#  ('2016', 'julia', 'nguyen'),
#  ('julia', 'nguyen', 'beating'),
#  ('nguyen', 'beating', 'burnout'),
#  ('beating', 'burnout', 'guide'),
#  ('burnout', 'guide', 'supporting'),
#  ('guide', 'supporting', 'mental'),
#  ('supporting', 'mental', 'health'),
#  ('mental', 'health', 'work'),
#  ('health', 'work', 'almanac'),
#  ('work', 'almanac', 'core'),
#  ('almanac', 'core', 'coding'),
#  ('core', 'coding', 'fast'),
#  ('coding', 'fast', 'slow'),
#  ('fast', 'slow', 'developer'),
#  ('slow', 'developer', 'psychology'),
#  ('developer', 'psychology', 'overconfidence'),
#  ('psychology', 'overconfidence', 'dan'),
#  ('overconfidence', 'dan', 'milstein'),
#  ('dan', 'milstein', 'depression'),
#  ('milstein', 'depression', 'work'),
#  ('depression', 'work', 'skyrocketing'),
#  ('work', 'skyrocketing', "'"),
#  ('skyrocketing', "'", 'new'),
#  ("'", 'new', 'normal'),
#  ('new', 'normal', 'bev'),
#  ('normal', 'bev', 'campling'),
#  ('bev', 'campling', 'developer'),
#  ('campling', 'developer', 'depression'),
#  ('developer', 'depression', 'isolation'),
#  ('depression', 'isolation', 'biggest'),
#  ('isolation', 'biggest', 'problem'),
#  ('biggest', 'problem', 'lauren'),
#  ('problem', 'lauren', 'maffeo'),
#  ('lauren', 'maffeo', 'developer'),
#  ('maffeo', 'developer', 'overcome'),
#  ('developer', 'overcome', 'imposter'),
#  ('overcome', 'imposter', 'syndrome'),
#  ('imposter', 'syndrome', 'abhishek'),
#  ('syndrome', 'abhishek', 'pillai'),
#  ('abhishek', 'pillai', 'disturb'),
#  ('pillai', 'disturb', 'joe'),
#  ('disturb', 'joe', 'bell'),
#  ('joe', 'bell', 'encouraging'),
#  ('bell', 'encouraging', 'wellness'),
#  ('encouraging', 'wellness', 'remote'),
#  ('wellness', 'remote', 'workpalce'),
#  ('remote', 'workpalce', 'desi'),
#  ('workpalce', 'desi', 'rottman'),
#  ('desi', 'rottman', 'developer'),
#  ('rottman', 'developer', 'anxiety'),
#  ('developer', 'anxiety', 'everyone'),
#  ('anxiety', 'everyone', 'else'),
#  ('everyone', 'else', 'daine'),
#  ('else', 'daine', 'mawer'),
#  ('daine', 'mawer', 'beat'),
#  ('mawer', 'beat', 'impostor'),
#  ('beat', 'impostor', 'syndrome'),
#  ('impostor', 'syndrome', 'stopped'),
#  ('syndrome', 'stopped', 'feeling'),
#  ('stopped', 'feeling', 'like'),
#  ('feeling', 'like', 'fake'),
#  ('like', 'fake', 'daragh'),
#  ('fake', 'daragh', 'byrne'),
#  ('daragh', 'byrne', 'conquered'),
#  ('byrne', 'conquered', 'anxiety'),
#  ('conquered', 'anxiety', 'learned'),
#  ('anxiety', 'learned', 'love'),
#  ('learned', 'love', 'coding'),
#  ('love', 'coding', 'joyce'),
#  ('coding', 'joyce', 'akiko'),
#  ('joyce', 'akiko', 'fought'),
#  ('akiko', 'fought', 'anxiety'),
#  ('fought', 'anxiety', 'depression'),
#  ('anxiety', 'depression', 'finish'),
#  ('depression', 'finish', 'freecodecamp'),
#  ('finish', 'freecodecamp', "'"),
#  ('freecodecamp', "'", 'front'),
#  ("'", 'front', 'end'),
#  ('front', 'end', 'dev'),
#  ('end', 'dev', 'program'),
#  ('dev', 'program', 'emily'),
#  ('program', 'emily', 'aamodt'),
#  ('emily', 'aamodt', 'keep'),
#  ('aamodt', 'keep', 'mental'),
#  ('keep', 'mental', 'health'),
#  ('mental', 'health', 'check'),
#  ('health', 'check', 'work'),
#  ('check', 'work', 'home'),
#  ('work', 'home', 'weworkremotely'),
#  ('home', 'weworkremotely', 'move'),
#  ('weworkremotely', 'move', 'organization'),
#  ('move', 'organization', 'fear'),
#  ('organization', 'fear', 'fearlessness'),
#  ('fear', 'fearlessness', 'gustavo'),
#  ('fearlessness', 'gustavo', 'razzetti'),
#  ('gustavo', 'razzetti', 'prevent'),
#  ('razzetti', 'prevent', 'recover'),
#  ('prevent', 'recover', 'developer'),
#  ('recover', 'developer', 'burnout'),
#  ('developer', 'burnout', 'anastasia'),
#  ('burnout', 'anastasia', 'hunting'),
#  ('anastasia', 'hunting', 'web'),
#  ('hunting', 'web', 'developer'),
#  ('web', 'developer', 'job'),
#  ('developer', 'job', 'crushing'),
#  ('job', 'crushing', 'anxiety'),
#  ('crushing', 'anxiety', 'selfesteem'),
#  ('anxiety', 'selfesteem', 'james'),
#  ('selfesteem', 'james', 'lave'),
#  ('james', 'lave', "'"),
#  ('lave', "'", 'burnout'),
#  ("'", 'burnout', 'story'),
#  ('burnout', 'story', 'molly'),
#  ('story', 'molly', 'struve'),
#  ('molly', 'struve', 'intro'),
#  ('struve', 'intro', 'meditation'),
#  ('intro', 'meditation', 'coder'),
#  ('meditation', 'coder', 'abe'),
#  ('coder', 'abe', 'dolinger'),
#  ('abe', 'dolinger', "'"),
#  ('dolinger', "'", 'okay'),
#  ("'", 'okay', 'okay'),
#  ('okay', 'okay', 'andrew'),
#  ('okay', 'andrew', 'montagne'),
#  ('andrew', 'montagne', "'"),
#  ('montagne', "'", 'time'),
#  ("'", 'time', 'talk'),
#  ('time', 'talk', 'mental'),
#  ('talk', 'mental', 'health'),
#  ('mental', 'health', 'game'),
#  ('health', 'game', 'industry'),
#  ('game', 'industry', 'rich'),
#  ('industry', 'rich', 'eddy'),
#  ('rich', 'eddy', "'"),
#  ('eddy', "'", 'time'),
#  ("'", 'time', 'talk'),
#  ('time', 'talk', 'mental'),
#  ('talk', 'mental', 'illness'),
#  ('mental', 'illness', 'indie'),
#  ('illness', 'indie', 'development'),
#  ('indie', 'development', 'jessica'),
#  ('development', 'jessica', 'conditt'),
#  ('jessica', 'conditt', 'mental'),
#  ('conditt', 'mental', 'self'),
#  ('mental', 'self', 'care'),
#  ('self', 'care', 'software'),
#  ('care', 'software', 'developer'),
#  ('software', 'developer', 'web'),
#  ('developer', 'web', 'designer'),
#  ('web', 'designer', 'bj'),
#  ('designer', 'bj', 'keeton'),
#  ('bj', 'keeton', 'mental'),
#  ('keeton', 'mental', 'illness'),
#  ('mental', 'illness', 'web'),
#  ('illness', 'web', 'industry'),
#  ('web', 'industry', 'brandon'),
#  ('industry', 'brandon', 'gregory'),
#  ('brandon', 'gregory', 'mental'),
#  ('gregory', 'mental', 'health'),
#  ('mental', 'health', 'toolbelt'),
#  ('health', 'toolbelt', 'taylor'),
#  ('toolbelt', 'taylor', 'otwell'),
#  ('taylor', 'otwell', 'dealing'),
#  ('otwell', 'dealing', 'anxiety'),
#  ('dealing', 'anxiety', 'depression'),
#  ('anxiety', 'depression', 'developer'),
#  ('depression', 'developer', 'michael'),
#  ('developer', 'michael', 'scott'),
#  ('michael', 'scott', 'hertzberg'),
#  ('scott', 'hertzberg', 'overcoming'),
#  ('hertzberg', 'overcoming', 'public'),
#  ('overcoming', 'public', 'speaking'),
#  ('public', 'speaking', 'anxiety'),
#  ('speaking', 'anxiety', 'software'),
#  ('anxiety', 'software', 'engineer'),
#  ('software', 'engineer', 'using'),
#  ('engineer', 'using', 'virtual'),
#  ('using', 'virtual', 'reality'),
#  ('virtual', 'reality', 'exposure'),
#  ('reality', 'exposure', 'therapy'),
#  ('exposure', 'therapy', 'merve'),
#  ('therapy', 'merve', 'denizci'),
#  ('merve', 'denizci', 'nazligul'),
#  ('denizci', 'nazligul', 'murat'),
#  ('nazligul', 'murat', 'yilmaz'),
#  ('murat', 'yilmaz', 'ulas'),
#  ('yilmaz', 'ulas', 'gulec'),
#  ('ulas', 'gulec', 'mert'),
#  ('gulec', 'mert', 'ali'),
#  ('mert', 'ali', 'gozcu'),
#  ('ali', 'gozcu', 'rory'),
#  ('gozcu', 'rory', 'v'),
#  ('rory', 'v', "'"),
#  ('v', "'", 'connor'),
#  ("'", 'connor', 'paul'),
#  ('connor', 'paul', 'clarke'),
#  ('paul', 'clarke', 'perfectionism'),
#  ('clarke', 'perfectionism', 'anxiety'),
#  ('perfectionism', 'anxiety', 'learning'),
#  ('anxiety', 'learning', 'kind'),
#  ('learning', 'kind', 'jo'),
#  ('kind', 'jo', 'franchetti'),
#  ('jo', 'franchetti', 'programmer'),
#  ('franchetti', 'programmer', 'imposter'),
#  ('programmer', 'imposter', 'syndrome'),
#  ('imposter', 'syndrome', '6'),
#  ('syndrome', '6', 'way'),
#  ('6', 'way', 'get'),
#  ('way', 'get', 'ethan'),
#  ('get', 'ethan', 'urie'),
#  ('ethan', 'urie', 'recovering'),
#  ('urie', 'recovering', 'burnout'),
#  ('recovering', 'burnout', 'kieran'),
#  ('burnout', 'kieran', 'tie'),
#  ('kieran', 'tie', 'software'),
#  ('tie', 'software', 'developer'),
#  ('software', 'developer', 'career'),
#  ('developer', 'career', 'considered'),
#  ('career', 'considered', 'harmful'),
#  ('considered', 'harmful', 'christian'),
#  ('harmful', 'christian', 'grobmeier'),
#  ('christian', 'grobmeier', 'sorry'),
#  ('grobmeier', 'sorry', 'sorry'),
#  ('sorry', 'sorry', 'advocate'),
#  ('sorry', 'advocate', 'mental'),
#  ('advocate', 'mental', 'health'),
#  ('mental', 'health', 'work'),
#  ('health', 'work', 'jessica'),
#  ('work', 'jessica', 'divento'),
#  ('jessica', 'divento', 'taming'),
#  ('divento', 'taming', 'anxiety'),
#  ('taming', 'anxiety', 'hacking'),
#  ('anxiety', 'hacking', 'way'),
#  ('hacking', 'way', 'productivity'),
#  ('way', 'productivity', 'andre'),
#  ('productivity', 'andre', 'pena'),
#  ('andre', 'pena', 'programmer'),
#  ('pena', 'programmer', 'great'),
#  ('programmer', 'great', 'clinical'),
#  ('great', 'clinical', 'depression'),
#  ('clinical', 'depression', 'jason'),
#  ('depression', 'jason', 'lowenthal'),
#  ('jason', 'lowenthal', 'tip'),
#  ('lowenthal', 'tip', 'dealing'),
#  ('tip', 'dealing', 'developer'),
#  ('dealing', 'developer', 'stress'),
#  ('developer', 'stress', 'rich'),
#  ('stress', 'rich', 'mclaughlin'),
#  ('rich', 'mclaughlin', 'tip'),
#  ('mclaughlin', 'tip', 'maintain'),
#  ('tip', 'maintain', 'mental'),
#  ('maintain', 'mental', 'health'),
#  ('mental', 'health', 'software'),
#  ('health', 'software', 'developer'),
#  ('software', 'developer', 'steven'),
#  ('developer', 'steven', 'need'),
#  ('steven', 'need', 'talk'),
#  ('need', 'talk', 'developer'),
#  ('talk', 'developer', 'depression'),
#  ('developer', 'depression', 'greg'),
#  ('depression', 'greg', 'baugues'),
#  ('greg', 'baugues', 'happens'),
#  ('baugues', 'happens', 'software'),
#  ('happens', 'software', 'developer'),
#  ('software', 'developer', 'unhappy'),
#  ('developer', 'unhappy', 'daniel'),
#  ('unhappy', 'daniel', 'graziotin'),
#  ('daniel', 'graziotin', 'fabian'),
#  ('graziotin', 'fabian', 'fagerholm'),
#  ('fabian', 'fagerholm', 'xiaofeng'),
#  ('fagerholm', 'xiaofeng', 'wang'),
#  ('xiaofeng', 'wang', 'pekka'),
#  ('wang', 'pekka', 'abrahamssone'),
#  ('pekka', 'abrahamssone', "'"),
#  ('abrahamssone', "'", 'like'),
#  ("'", 'like', 'developer'),
#  ('like', 'developer', 'schizoaffective'),
#  ('developer', 'schizoaffective', 'disorder'),
#  ('schizoaffective', 'disorder', 'fri'),
#  ('disorder', 'fri', 'remote'),
#  ('fri', 'remote', 'company'),
#  ('remote', 'company', "'"),
#  ('company', "'", 'tell'),
#  ("'", 'tell', 'remote'),
#  ('tell', 'remote', 'work'),
#  ('remote', 'work', 'amir'),
#  ('work', 'amir', 'salihefendic'),
#  ('amir', 'salihefendic', 'burnout'),
#  ('salihefendic', 'burnout', 'dangerous'),
#  ('burnout', 'dangerous', 'recover'),
#  ('dangerous', 'recover', "'"),
#  ('recover', "'", 'possible'),
#  ("'", 'possible', 'theodora'),
#  ('possible', 'theodora', 'abigail'),
#  ('theodora', 'abigail', 'software'),
#  ('abigail', 'software', 'developer'),
#  ('software', 'developer', 'suffer'),
#  ('developer', 'suffer', 'imposter'),
#  ('suffer', 'imposter', 'syndrome'),
#  ('imposter', 'syndrome', 'muhammed'),
#  ('syndrome', 'muhammed', 'rajeef'),
#  ('muhammed', 'rajeef', 'k'),
#  ('rajeef', 'k', 'booksbooks'),
#  ('k', 'booksbooks', 'mental'),
#  ('booksbooks', 'mental', 'health'),
#  ('mental', 'health', 'selfcare'),
#  ('health', 'selfcare', 'main'),
#  ('selfcare', 'main', 'theme'),
#  ('main', 'theme', 'mental'),
#  ('theme', 'mental', 'health'),
#  ('mental', 'health', 'tech'),
#  ('health', 'tech', 'guideline'),
#  ('tech', 'guideline', 'employee'),
#  ('guideline', 'employee', 'osmi'),
#  ('employee', 'osmi', 'mental'),
#  ('osmi', 'mental', 'health'),
#  ('mental', 'health', 'tech'),
#  ('health', 'tech', 'guideline'),
#  ('tech', 'guideline', 'executive'),
#  ('guideline', 'executive', 'hr'),
#  ('executive', 'hr', 'professional'),
#  ('hr', 'professional', 'osmi'),
#  ('professional', 'osmi', 'mental'),
#  ('osmi', 'mental', 'health'),
#  ('mental', 'health', 'tech'),
#  ('health', 'tech', 'guideline'),
#  ('tech', 'guideline', 'mental'),
#  ('guideline', 'mental', 'wellness'),
#  ('mental', 'wellness', 'workplace'),
#  ('wellness', 'workplace', 'osmi'),
#  ('workplace', 'osmi', 'conferencesconferences'),
#  ('osmi', 'conferencesconferences', 'spreading'),
#  ('conferencesconferences', 'spreading', 'word'),
#  ('spreading', 'word', 'importance'),
#  ('word', 'importance', 'mental'),
#  ('importance', 'mental', 'health'),
#  ('mental', 'health', 'awareness'),
#  ('health', 'awareness', 'selfcare'),
#  ('awareness', 'selfcare', 'software'),
#  ('selfcare', 'software', 'industry'),
#  ('software', 'industry', 'computing'),
#  ('industry', 'computing', 'mental'),
#  ('computing', 'mental', 'health'),
#  ('mental', 'health', 'bringing'),
#  ('health', 'bringing', 'together'),
#  ('bringing', 'together', 'community'),
#  ('together', 'community', 'anxiety'),
#  ('community', 'anxiety', 'tech'),
#  ('anxiety', 'tech', 'learn'),
#  ('tech', 'learn', 'advocate'),
#  ('learn', 'advocate', 'mental'),
#  ('advocate', 'mental', 'health'),
#  ('mental', 'health', 'work'),
#  ('health', 'work', 'technology'),
#  ('work', 'technology', 'better'),
#  ('technology', 'better', 'designed'),
#  ('better', 'designed', 'support'),
#  ('designed', 'support', 'mental'),
#  ('support', 'mental', 'health'),
#  ('mental', 'health', 'technology'),
#  ('health', 'technology', 'already'),
#  ('technology', 'already', 'working'),
#  ('already', 'working', 'help'),
#  ('working', 'help', 'suffer'),
#  ('help', 'suffer', 'mental'),
#  ('suffer', 'mental', 'illness'),
#  ('mental', 'illness', 'company'),
#  ('illness', 'company', 'leader'),
#  ('company', 'leader', 'field'),
#  ('leader', 'field', 'meetupsmeetup'),
#  ('field', 'meetupsmeetup', 'group'),
#  ('meetupsmeetup', 'group', 'around'),
#  ('group', 'around', 'world'),
#  ('around', 'world', 'focusing'),
#  ('world', 'focusing', 'mental'),
#  ('focusing', 'mental', 'health'),
#  ('mental', 'health', 'software'),
#  ('health', 'software', 'industry'),
#  ('software', 'industry', 'mental'),
#  ('industry', 'mental', 'health'),
#  ('mental', 'health', 'tech'),
#  ('health', 'tech', 'auckland'),
#  ('tech', 'auckland', 'organized'),
#  ('auckland', 'organized', 'navs'),
#  ('organized', 'navs', 'kai'),
#  ('navs', 'kai', 'l'),
#  ('kai', 'l', 'helen'),
#  ('l', 'helen', 'organizationsorganizations'),
#  ('helen', 'organizationsorganizations', 'bringing'),
#  ('organizationsorganizations', 'bringing', 'mental'),
#  ('bringing', 'mental', 'health'),
#  ('mental', 'health', 'awareness'),
#  ('health', 'awareness', 'software'),
#  ('awareness', 'software', 'industry'),
#  ('software', 'industry', 'black'),
#  ('industry', 'black', 'mind'),
#  ('black', 'mind', 'matter'),
#  ('mind', 'matter', 'nonprofit'),
#  ('matter', 'nonprofit', 'organisation'),
#  ('nonprofit', 'organisation', 'aim'),
#  ('organisation', 'aim', 'empower'),
#  ('aim', 'empower', 'community'),
#  ('empower', 'community', 'black'),
#  ('community', 'black', 'people'),
#  ('black', 'people', 'aged'),
#  ('people', 'aged', '13'),
#  ('aged', '13', '25'),
#  ('13', '25', 'want'),
#  ('25', 'want', 'make'),
#  ('want', 'make', 'equal'),
#  ('make', 'equal', 'society'),
#  ('equal', 'society', 'black'),
#  ('society', 'black', 'therapist'),
#  ('black', 'therapist', 'rock'),
#  ('therapist', 'rock', 'black'),
#  ('rock', 'black', 'therapist'),
#  ('black', 'therapist', 'rock'),
#  ('therapist', 'rock', 'btr'),
#  ('rock', 'btr', 'organization'),
#  ('btr', 'organization', 'committed'),
#  ('organization', 'committed', 'increasing'),
#  ('committed', 'increasing', 'awareness'),
#  ('increasing', 'awareness', 'social'),
#  ('awareness', 'social', 'psychological'),
#  ('social', 'psychological', 'challenge'),
#  ('psychological', 'challenge', 'impacting'),
#  ('challenge', 'impacting', 'vulnerable'),
#  ('impacting', 'vulnerable', 'community'),
#  ('vulnerable', 'community', 'black'),
#  ('community', 'black', 'african'),
#  ('black', 'african', 'asian'),
#  ('african', 'asian', 'therapy'),
#  ('asian', 'therapy', 'network'),
#  ('therapy', 'network', 'uk'),
#  ('network', 'uk', 'largest'),
#  ('uk', 'largest', 'independent'),
#  ('largest', 'independent', 'organisation'),
#  ('independent', 'organisation', 'specialise'),
#  ('organisation', 'specialise', 'working'),
#  ('specialise', 'working', 'psychologically'),
#  ('working', 'psychologically', 'informed'),
#  ('psychologically', 'informed', 'understanding'),
#  ('informed', 'understanding', 'intersectionality'),
#  ('understanding', 'intersectionality', 'people'),
#  ('intersectionality', 'people', 'identify'),
#  ('people', 'identify', 'black'),
#  ('identify', 'black', 'african'),
#  ('black', 'african', 'south'),
#  ('african', 'south', 'asian'),
#  ('south', 'asian', 'caribbean'),
#  ('asian', 'caribbean', 'brown'),
#  ('caribbean', 'brown', 'sister'),
#  ('brown', 'sister', 'speak'),
#  ('sister', 'speak', 'mental'),
#  ('speak', 'mental', 'health'),
#  ('mental', 'health', 'peer'),
#  ('health', 'peer', 'support'),
#  ('peer', 'support', 'advocacy'),
#  ('support', 'advocacy', 'woman'),
#  ('advocacy', 'woman', 'color'),
#  ('woman', 'color', 'compassionate'),
#  ('color', 'compassionate', 'coding'),
#  ('compassionate', 'coding', 'compassionate'),
#  ('coding', 'compassionate', 'coding'),
#  ('compassionate', 'coding', 'combine'),
#  ('coding', 'combine', 'effective'),
#  ('combine', 'effective', 'practice'),
#  ('effective', 'practice', 'agile'),
#  ('practice', 'agile', 'software'),
#  ('agile', 'software', 'development'),
#  ('software', 'development', 'focus'),
#  ('development', 'focus', 'empathy'),
#  ('focus', 'empathy', 'latest'),
#  ('empathy', 'latest', 'positive'),
#  ('latest', 'positive', 'organizational'),
#  ('positive', 'organizational', 'psychology'),
#  ('organizational', 'psychology', 'everybody'),
#  ('psychology', 'everybody', 'brain'),
#  ('everybody', 'brain', 'everybody'),
#  ('brain', 'everybody', 'brain'),
#  ('everybody', 'brain', 'creating'),
#  ('brain', 'creating', 'opportunity'),
#  ('creating', 'opportunity', 'dialogue'),
#  ('opportunity', 'dialogue', 'around'),
#  ('dialogue', 'around', 'personal'),
#  ('around', 'personal', 'mental'),
#  ('personal', 'mental', 'health'),
#  ('mental', 'health', 'hack'),
#  ('health', 'hack', 'mental'),
#  ('hack', 'mental', 'health'),
#  ('mental', 'health', 'intersection'),
#  ('health', 'intersection', 'mental'),
#  ('intersection', 'mental', 'health'),
#  ('mental', 'health', 'technology'),
#  ('health', 'technology', 'ifme'),
#  ('technology', 'ifme', 'community'),
#  ('ifme', 'community', 'mental'),
#  ('community', 'mental', 'health'),
#  ('mental', 'health', 'experience'),
#  ('health', 'experience', 'encourages'),
#  ('experience', 'encourages', 'people'),
#  ('encourages', 'people', 'share'),
#  ('people', 'share', 'personal'),
#  ('share', 'personal', 'story'),
#  ('personal', 'story', 'trusted'),
#  ('story', 'trusted', 'ally'),
#  ('trusted', 'ally', 'mental'),
#  ('ally', 'mental', 'health'),
#  ('mental', 'health', 'hacker'),
#  ('health', 'hacker', 'organization'),
#  ('hacker', 'organization', 'aim'),
#  ('organization', 'aim', 'providing'),
#  ('aim', 'providing', 'support'),
#  ('providing', 'support', 'service'),
#  ('support', 'service', 'may'),
#  ('service', 'may', 'susceptible'),
#  ('may', 'susceptible', 'related'),
#  ('susceptible', 'related', 'mental'),
#  ('related', 'mental', 'health'),
#  ('mental', 'health', 'issue'),
#  ('health', 'issue', 'anxiety'),
#  ('issue', 'anxiety', 'depression'),
#  ('anxiety', 'depression', 'social'),
#  ('depression', 'social', 'isolation'),
#  ('social', 'isolation', 'eating'),
#  ('isolation', 'eating', 'disorder'),
#  ('eating', 'disorder', 'etc'),
#  ('disorder', 'etc', 'mental'),
#  ('etc', 'mental', 'health'),
#  ('mental', 'health', 'knowledge'),
#  ('health', 'knowledge', 'base'),
#  ('knowledge', 'base', 'githubbased'),
#  ('base', 'githubbased', 'project'),
#  ('githubbased', 'project', 'website'),
#  ('project', 'website', 'encourages'),
#  ('website', 'encourages', 'diversity'),
#  ('encourages', 'diversity', 'view'),
#  ('diversity', 'view', 'regarding'),
#  ('view', 'regarding', 'mental'),
#  ('regarding', 'mental', 'health'),
#  ('mental', 'health', 'mhprompt'),
#  ('health', 'mhprompt', 'let'),
#  ('mhprompt', 'let', "'"),
#  ('let', "'", 'start'),
#  ("'", 'start', 'conversation'),
#  ('start', 'conversation', 'mental'),
#  ('conversation', 'mental', 'health'),
#  ('mental', 'health', 'tech'),
#  ('health', 'tech', 'osmi'),
#  ('tech', 'osmi', 'open'),
#  ('osmi', 'open', 'sourcing'),
#  ('open', 'sourcing', 'mental'),
#  ('sourcing', 'mental', 'illness'),
#  ('mental', 'illness', 'nonprofit'),
#  ('illness', 'nonprofit', 'corporation'),
#  ('nonprofit', 'corporation', 'dedicated'),
#  ('corporation', 'dedicated', 'raising'),
#  ('dedicated', 'raising', 'awareness'),
#  ('raising', 'awareness', 'educating'),
#  ('awareness', 'educating', 'providing'),
#  ('educating', 'providing', 'resource'),
#  ('providing', 'resource', 'support'),
#  ('resource', 'support', 'mental'),
#  ('support', 'mental', 'wellness'),
#  ('mental', 'wellness', 'tech'),
#  ('wellness', 'tech', 'open'),
#  ('tech', 'open', 'source'),
#  ('open', 'source', 'community'),
#  ('source', 'community', 'selfcaretech'),
#  ('community', 'selfcaretech', 'repository'),
#  ('selfcaretech', 'repository', 'selfcare'),
#  ('repository', 'selfcare', 'resource'),
#  ('selfcare', 'resource', 'developer'),
#  ('resource', 'developer', 'others'),
#  ('developer', 'others', 'podcastspodcast'),
#  ('others', 'podcastspodcast', 'episode'),
#  ('podcastspodcast', 'episode', 'mental'),
#  ('episode', 'mental', 'health'),
#  ('mental', 'health', 'awareness'),
#  ('health', 'awareness', 'software'),
#  ('awareness', 'software', 'industry'),
#  ('software', 'industry', 'main'),
#  ('industry', 'main', 'theme'),
#  ('main', 'theme', 'emotional'),
#  ('theme', 'emotional', 'intelligence'),
#  ('emotional', 'intelligence', 'ethic'),
#  ('intelligence', 'ethic', 'tech'),
#  ('ethic', 'tech', 'april'),
#  ('tech', 'april', 'wensel'),
#  ('april', 'wensel', 'happy'),
#  ('wensel', 'happy', 'porch'),
#  ('happy', 'porch', 'podcast'),
#  ('porch', 'podcast', 'jerk'),
#  ('podcast', 'jerk', 'programmer'),
#  ('jerk', 'programmer', 'compassionate'),
#  ('programmer', 'compassionate', 'coder'),
#  ('compassionate', 'coder', 'april'),
#  ('coder', 'april', 'wensel'),
#  ('april', 'wensel', 'ardent'),
#  ('wensel', 'ardent', 'development'),
#  ('ardent', 'development', 'podcast'),
#  ('development', 'podcast', 'talkstalks'),
#  ('podcast', 'talkstalks', 'presentation'),
#  ('talkstalks', 'presentation', 'mental'),
#  ('presentation', 'mental', 'health'),
#  ('mental', 'health', 'awareness'),
#  ('health', 'awareness', 'testimony'),
#  ('awareness', 'testimony', 'experience'),
#  ('testimony', 'experience', 'software'),
#  ('experience', 'software', 'industry'),
#  ('software', 'industry', 'conversation'),
#  ('industry', 'conversation', 'mental'),
#  ('conversation', 'mental', 'health'),
#  ('mental', 'health', 'tech'),
#  ('health', 'tech', 'distill'),
#  ('tech', 'distill', '2014'),
#  ('distill', '2014', 'ed'),
#  ('2014', 'ed', 'finkler'),
#  ('ed', 'finkler', 'greg'),
#  ('finkler', 'greg', 'baugues'),
#  ('greg', 'baugues', 'john'),
#  ('baugues', 'john', 'dalton'),
#  ('john', 'dalton', 'paddy'),
#  ('dalton', 'paddy', 'foran'),
#  ('paddy', 'foran', 'advocating'),
#  ('foran', 'advocating', 'mental'),
#  ('advocating', 'mental', 'health'),
#  ('mental', 'health', 'work'),
#  ('health', 'work', 'anxietytech'),
#  ('work', 'anxietytech', '2018'),
#  ('anxietytech', '2018', 'dr'),
#  ('2018', 'dr', 'jessica'),
#  ('dr', 'jessica', 'divento'),
#  ('jessica', 'divento', 'anxiety'),
#  ('divento', 'anxiety', 'calm'),
#  ('anxiety', 'calm', 'technology'),
#  ('calm', 'technology', 'anxietytech'),
#  ('technology', 'anxietytech', '2018'),
#  ('anxietytech', '2018', 'amber'),
#  ('2018', 'amber', 'case'),
#  ('amber', 'case', 'authentic'),
#  ('case', 'authentic', 'developer'),
#  ('authentic', 'developer', 'droidcon'),
#  ('developer', 'droidcon', 'berlin'),
#  ('droidcon', 'berlin', '2018'),
#  ('berlin', '2018', 'anastasia'),
#  ('2018', 'anastasia', 'lopez'),
#  ('anastasia', 'lopez', 'dornak'),
#  ('lopez', 'dornak', 'beyond'),
#  ('dornak', 'beyond', 'burnout'),
#  ('beyond', 'burnout', 'mental'),
#  ('burnout', 'mental', 'health'),
#  ('mental', 'health', 'neurodiversity'),
#  ('health', 'neurodiversity', 'engineering'),
#  ('neurodiversity', 'engineering', 'devopsdays'),
#  ('engineering', 'devopsdays', 'boston'),
#  ('devopsdays', 'boston', '2018'),
#  ('boston', '2018', 'james'),
#  ('2018', 'james', 'meickle'),
#  ('james', 'meickle', 'burnout'),
#  ('meickle', 'burnout', 'meat'),
#  ('burnout', 'meat', 'computer'),
#  ('meat', 'computer', 'electromagnetic'),
#  ('computer', 'electromagnetic', 'field'),
#  ('electromagnetic', 'field', '2018'),
#  ('field', '2018', 'jessica'),
#  ('2018', 'jessica', 'rose'),
#  ('jessica', 'rose', 'cultivating'),
#  ('rose', 'cultivating', 'compassionate'),
#  ('cultivating', 'compassionate', 'tech'),
#  ('compassionate', 'tech', 'community'),
#  ('tech', 'community', 'anxietytech'),
#  ('community', 'anxietytech', '2018'),
#  ('anxietytech', '2018', 'april'),
#  ('2018', 'april', 'wensel'),
#  ('april', 'wensel', 'debugging'),
#  ('wensel', 'debugging', 'feeling'),
#  ('debugging', 'feeling', 'cognitive'),
#  ('feeling', 'cognitive', 'behavioural'),
#  ('cognitive', 'behavioural', 'therapy'),
#  ('behavioural', 'therapy', 'developer'),
#  ('therapy', 'developer', 'peer'),
#  ('developer', 'peer', 'conference'),
#  ('peer', 'conference', '2018'),
#  ('conference', '2018', 'jamie'),
#  ('2018', 'jamie', 'strachan'),
#  ('jamie', 'strachan', 'developer'),
#  ('strachan', 'developer', 'depression'),
#  ('developer', 'depression', 'codeland'),
#  ('depression', 'codeland', 'nyc'),
#  ('codeland', 'nyc', '2017'),
#  ('nyc', '2017', 'greg'),
#  ('2017', 'greg', 'baugues'),
#  ('greg', 'baugues', 'developer'),
#  ('baugues', 'developer', 'entrepreneur'),
#  ('developer', 'entrepreneur', 'depression'),
#  ('entrepreneur', 'depression', 'business'),
#  ('depression', 'business', 'software'),
#  ('business', 'software', '2015'),
#  ('software', '2015', 'greg'),
#  ('2015', 'greg', 'baugues'),
#  ('greg', 'baugues', 'emotional'),
#  ('baugues', 'emotional', 'intelligence'),
#  ('emotional', 'intelligence', 'engineer'),
#  ('intelligence', 'engineer', 'ngatlanta'),
#  ('engineer', 'ngatlanta', '2018'),
#  ('ngatlanta', '2018', 'april'),
#  ('2018', 'april', 'wensel'),
#  ('april', 'wensel', 'fight'),
#  ('wensel', 'fight', 'tech'),
#  ('fight', 'tech', 'tech'),
#  ('tech', 'tech', 'anxietytech'),
#  ('tech', 'anxietytech', '2018'),
#  ('anxietytech', '2018', 'pamela'),
#  ('2018', 'pamela', 'fox'),
#  ('pamela', 'fox', 'getting'),
#  ('fox', 'getting', 'therapy'),
#  ('getting', 'therapy', 'need'),
#  ('therapy', 'need', 'anxietytech'),
#  ('need', 'anxietytech', '2018'),
#  ('anxietytech', '2018', 'shawn'),
#  ('2018', 'shawn', 'kernes'),
#  ('shawn', 'kernes', 'hacking'),
#  ('kernes', 'hacking', 'anxiety'),
#  ('hacking', 'anxiety', 'anxietytech'),
#  ('anxiety', 'anxietytech', '2018'),
#  ('anxietytech', '2018', 'bryan'),
#  ('2018', 'bryan', 'hughes'),
#  ('bryan', 'hughes', 'hitting'),
#  ('hughes', 'hitting', 'wall'),
#  ('hitting', 'wall', 'get'),
#  ('wall', 'get', 'tackling'),
#  ('get', 'tackling', 'burnout'),
#  ('tackling', 'burnout', 'strategy'),
#  ('burnout', 'strategy', 'self'),
#  ('strategy', 'self', 'care'),
#  ('self', 'care', 'pycon'),
#  ('care', 'pycon', 'australia'),
#  ('pycon', 'australia', '2016'),
#  ('australia', '2016', 'jackson'),
#  ('2016', 'jackson', 'fairchild'),
#  ('jackson', 'fairchild', 'howto'),
#  ('fairchild', 'howto', 'get'),
#  ('howto', 'get', 'burnout'),
#  ('get', 'burnout', 'powershell'),
#  ('burnout', 'powershell', 'conference'),
#  ('powershell', 'conference', 'eu'),
#  ('conference', 'eu', '2018'),
#  ('eu', '2018', 'jeff'),
#  ('2018', 'jeff', 'wouters'),
#  ('jeff', 'wouters', 'imposter'),
#  ('wouters', 'imposter', 'syndrome'),
#  ('imposter', 'syndrome', 'pycon'),
#  ('syndrome', 'pycon', 'australia'),
#  ('pycon', 'australia', '2016'),
#  ('australia', '2016', 'bianca'),
#  ('2016', 'bianca', 'gibson'),
#  ('bianca', 'gibson', "'"),
#  ('gibson', "'", 'dangerous'),
#  ("'", 'dangerous', 'go'),
#  ('dangerous', 'go', 'alone'),
#  ('go', 'alone', 'battling'),
#  ('alone', 'battling', 'invisible'),
#  ('battling', 'invisible', 'monster'),
#  ('invisible', 'monster', 'tech'),
#  ('monster', 'tech', 'pycon'),
#  ('tech', 'pycon', '2014'),
#  ('pycon', '2014', 'julie'),
#  ('2014', 'julie', 'pagano'),
#  ('julie', 'pagano', "'"),
#  ('pagano', "'", 'darkest'),
#  ("'", 'darkest', 'dawn'),
#  ('darkest', 'dawn', 'alcoholism'),
#  ('dawn', 'alcoholism', 'addiction'),
#  ('alcoholism', 'addiction', 'tech'),
#  ('addiction', 'tech', 'djangocon'),
#  ('tech', 'djangocon', 'u'),
#  ('djangocon', 'u', '2016'),
#  ('u', '2016', 'timothy'),
#  ('2016', 'timothy', 'allen'),
#  ('timothy', 'allen', 'living'),
#  ('allen', 'living', 'bipolar'),
#  ('living', 'bipolar', 'disorder'),
#  ('bipolar', 'disorder', 'software'),
#  ('disorder', 'software', 'engineer'),
#  ('software', 'engineer', 'anxietytech'),
#  ('engineer', 'anxietytech', '2018'),
#  ('anxietytech', '2018', 'jenna'),
#  ('2018', 'jenna', 'quindica'),
#  ('jenna', 'quindica', 'looking'),
#  ('quindica', 'looking', 'mental'),
#  ('looking', 'mental', 'health'),
#  ('mental', 'health', 'guide'),
#  ('health', 'guide', 'software'),
#  ('guide', 'software', 'developer'),
#  ('software', 'developer', 'php'),
#  ('developer', 'php', 'yorkshire'),
#  ('php', 'yorkshire', '2018'),
#  ('yorkshire', '2018', 'mark'),
#  ('2018', 'mark', 'railton'),
#  ('mark', 'railton', 'mental'),
#  ('railton', 'mental', 'health'),
#  ('mental', 'health', 'development'),
#  ('health', 'development', 'pycon'),
#  ('development', 'pycon', 'australia'),
#  ('pycon', 'australia', '2016'),
#  ('australia', '2016', 'eloise'),
#  ...]

# %%
tri_counts = Counter(trigrams)
print (tri_counts)
# Out:
# Counter({("'", 'section', "'"): 34, ('nbsp', 'nbsp', 'nbsp'): 27, ("'", 'help', "'"): 26, ("'", 'home', "'"): 25, ('mental', 'health', 'issue'): 24, ('section', "'", 'help'): 22, ('mental', 'health', 'tech'): 21, ("'", 'spread', 'word'): 21, ('spread', 'word', "'"): 21, ('home', "'", 'page'): 17, ("'", 'sign', "'"): 17, ("'", 'page', 'user'): 17, ("'", 'mental', 'health'): 16, ('mental', 'health', 'disorder'): 16, ("'", 'help', 'others'): 16, ('help', 'others', "'"): 16, ('front', 'line', 'worker'): 16, ('mental', 'health', 'problem'): 15, ('help', "'", 'page'): 15, ('word', "'", 'page'): 15, ("'", 'educate', "'"): 14, ('mental', 'health', 'awareness'): 13, ("'", 'resource', "'"): 13, ('member', 'github', 'team'): 12, ('github', 'team', 'member'): 12, ('team', 'member', 'social'): 12, ('mental', 'health', 'condition'): 11, ('resource', "'", 'section'): 11, ('showing', 'first', 'part'): 11, ('first', 'part', "'"): 11, ('hide', 'feed', 'home'): 10, ('feed', 'home', 'page'): 10, ('others', "'", 'page'): 10, ('user', 'want', 'able'): 9, ('awareness', 'mental', 'health'): 9, ('sign', "'", 'page'): 9, ('image', 'showing', 'first'): 9, ('member', 'social', 'linkedinteam'): 9, ('social', 'linkedinteam', 'member'): 9, ('linkedinteam', 'member', 'name'): 9, ('mental', 'health', 'care'): 8, ('create', 'react', 'app'): 8, ('world', 'mental', 'health'): 8, ('section', "'", 'spread'): 8, ('educate', "'", 'page'): 8, ('related', 'mental', 'health'): 7, ('install', 'r', 'requirementstxt'): 7, ('struggling', 'mental', 'health'): 7, ('autisticaturing', 'citizen', 'science'): 7, ('run', 'following', 'command'): 7, ('people', 'mental', 'health'): 7, ('mental', 'health', 'day'): 7, ('mental', 'health', 'work'): 6, ('mental', 'health', 'app'): 6, ('git', 'clone', 'cd'): 6, ('bootstrapped', 'create', 'react'): 6, ('project', 'directory', 'run'): 6, ("'", 'lex', "'"): 6, ('mental', 'health', 'support'): 6, ('init', 'messagespot', 'babel'): 6, ('messagespot', 'babel', 'l'): 6, ('suffer', 'mental', 'health'): 6, ('talking', 'mental', 'health'): 6, ('section', "'", 'home'): 6, ('world', 'health', 'organization'): 6, ("'", 'suicide', 'hotlines'): 6, ('suicide', 'hotlines', "'"): 6, ('user', 'come', 'across'): 6, ("'", 'subsection', "'"): 6, ("'", 'acquaintance', 'struggling'): 6, ('acquaintance', 'struggling', "'"): 6, ('struggling', "'", 'section'): 6, ('install', 'development', 'version'): 6, ('development', 'version', 'software'): 6, ('version', 'software', 'run'): 6, ('software', 'run', 'following'): 6, ('following', 'command', 'r'): 6, ('cognitive', 'behavioral', 'therapy'): 5, ('mental', 'health', 'technology'): 5, ('support', 'mental', 'health'): 5, ('open', 'source', 'community'): 5, ('page', 'reload', 'make'): 5, ('also', 'see', 'lint'): 5, ('see', 'lint', 'error'): 5, ('testlaunches', 'test', 'runner'): 5, ('test', 'runner', 'interactive'): 5, ('runner', 'interactive', 'watch'): 5, ("'", "'", "'"): 5, ('home', 'page', 'support'): 5, ('project', 'bootstrapped', 'create'): 5, ("'", 'match', "'"): 5, ('mental', 'health', 'wellbeing'): 5, ('accomplishment', "'", 'proud'): 5, ('electronic', 'health', 'record'): 5, ('disorder', 'depression', 'anxiety'): 5, ('git', 'checkout', 'b'): 5, ('git', 'commit', "'"): 5, ('know', 'mental', 'health'): 5, ('mental', 'health', 'emergency'): 5, ('health', 'emergency', "'"): 5, ('emergency', "'", 'section'): 5, ('hotlines', "'", 'section'): 5, ("'", 'shop', "'"): 5, ("'", 'page', 'image'): 5, ('page', 'user', 'come'): 5, ("'", 'specific', 'disorder'): 5, ('specific', 'disorder', "'"): 5, ('disorder', "'", 'section'): 5, ('r', 'package', 'version'): 5, ('improve', 'mental', 'health'): 5, ('suc', 'khoe', 'tinh'): 5, ('run', 'php', 'artisan'): 5, ('state', 'mental', 'health'): 4, ('maintain', 'mental', 'health'): 4, ('importance', 'mental', 'health'): 4, ('mental', 'health', 'professional'): 4, ('let', 'know', "'"): 4, ('pip', 'install', 'r'): 4, ('depression', 'anxiety', 'ptsd'): 4, ('analysis', 'questioningusing', ' ...

# %%
top = tri_counts.most_common(10)
print (top)
# Out:
# [(("'", 'section', "'"), 34), (('nbsp', 'nbsp', 'nbsp'), 27), (("'", 'help', "'"), 26), (("'", 'home', "'"), 25), (('mental', 'health', 'issue'), 24), (('section', "'", 'help'), 22), (('mental', 'health', 'tech'), 21), (("'", 'spread', 'word'), 21), (('spread', 'word', "'"), 21), (('home', "'", 'page'), 17)]

# %%
# df['bigrams'] = all_words.apply(lambda row: list(nltk.ngrams(row, 2)))

# %%
# from nltk.util import ngrams

# n = 2
# bigrams = all_words.apply(lambda x:" ".join(x for x in x.split(), n))

# %%
df
# Out:
#                                         repo    language  \
# 0       dreamingechoes/awesome-mental-health        HTML
# 1                               Flaque/quirk  TypeScript
# 4                       sepandhaghighi/nafas      Python
# 5                     youarerad/youareradweb  TypeScript
# 7                 OSMIHelp/osmi-survey-graph         PHP
# ..                                       ...         ...
# 380             EdwardRees/Self-Care-Project  TypeScript
# 384   sumantchirde/Mental-Health-NLP-project      Python
# 385                        Levodex/RipplerPy  JavaScript
# 387                    acfromspace/soulstone        HTML
# 390  brunomontezano/gender-and-mental-health           R
#
#                                        readme_contents  \
# 0    \n<p align="center"><img src="./media/logo.png...
# 1    🚧🚧🚧\n\n**Quirk is no longer being maintained.*...
# 4    <div align="center">\n<img src="https://github...
# 5    <div align="center"><img src="https://res.clou...
# 7    # 2016 OSMI Survey Graph\n\n## Installing and ...
# ..                                                 ...
# 380  # Self Care Project\n\nWhat used to be a Menta...
# 384  #  Mental health assessment by NLP and ML usin...
# 385  ## About\n* \n* (Read github/bitbucket descrip...
# 387  <!-- HEADING -->\n\n<h1 align="center">soulsto...
# 390  # Prevalência de transtornos mentais entre gên...
#
#                                                stemmed  \
# 0    aboutsparkl curat list awesom articl websit re...
# 1    quirk longer maintainedquirk start littl thing...
# 4    nafa &#9; tabl content overview instal usag is...
# 5    welcom rise disord ' websit repow nonprofit co...
# 7    2016 osmi survey graph instal run copi envexam...
# ..                                                 ...
# 380  self care projectwhat use mental health projec...
# 384  mental health assess nlp ml use tensorflownowa...
# 385  read githubbitbucket descript copyright notice...
# 387  soulstoneperson reflect thought one ' selfswee...
# 390  prevalencia de transtorno mentai entr genero p...
#
#                                             lemmatized  total_words  \
# 0    aboutsparkles curated list awesome article web...         1140
# 1    quirk longer maintainedquirk started little th...         1061
# 4    nafas &#9; table content overview installation...          351
# 5    welcome rise disorder ' website repowe nonprof...           83
# 7    2016 osmi survey graph installing running copy...          419
# ..                                                 ...          ...
# 380  self care projectwhat used mental health proje...           49
# 384  mental health assessment nlp ml using tensorfl...           88
# 385  read githubbitbucket description copyright not...          155
# 387  soulstonepersonal reflection thought one ' sel...           15
# 390  prevalencia de transtornos mentais entre gener...          101
#
#       count_bin
# 0    high_count
# 1    high_count
# 4    high_count
# 5     med_count
# 7    high_count
# ..          ...
# 380   low_count
# 384   med_count
# 385   med_count
# 387   low_count
# 390   med_count
#
# [238 rows x 7 columns]

# %%
df = df[df.language!='Vue']
df = df[df.language!='PHP']
df = df[df.language!='C++']
#, 'PHP', 'C++']

# %%
df.head()
# Out:
#                                    repo    language  \
# 0  dreamingechoes/awesome-mental-health        HTML
# 1                          Flaque/quirk  TypeScript
# 4                  sepandhaghighi/nafas      Python
# 5                youarerad/youareradweb  TypeScript
# 8                     chroline/well_app        Dart
#
#                                      readme_contents  \
# 0  \n<p align="center"><img src="./media/logo.png...
# 1  🚧🚧🚧\n\n**Quirk is no longer being maintained.*...
# 4  <div align="center">\n<img src="https://github...
# 5  <div align="center"><img src="https://res.clou...
# 8  ![The Well App](thumbnail.png)\n\n<div align='...
#
#                                              stemmed  \
# 0  aboutsparkl curat list awesom articl websit re...
# 1  quirk longer maintainedquirk start littl thing...
# 4  nafa &#9; tabl content overview instal usag is...
# 5  welcom rise disord ' websit repow nonprofit co...
# 8  well appthumbnailpng quick link well app avail...
#
#                                           lemmatized  total_words   count_bin
# 0  aboutsparkles curated list awesome article web...         1140  high_count
# 1  quirk longer maintainedquirk started little th...         1061  high_count
# 4  nafas &#9; table content overview installation...          351  high_count
# 5  welcome rise disorder ' website repowe nonprof...           83   med_count
# 8  well appthumbnailpng quick link well app avail...          320  high_count

# %%
top_20_bigrams = (pd.Series(nltk.ngrams(all_words, 2))
                      .value_counts()
                      .head(20))

top_20_bigrams.head(20)
# Out:
# (br, br)               77
# (p, aligncenter)       48
# (img, src)             48
# (home, page)           48
# (nbsp, nbsp)           46
# (team, member)         44
# (git, clone)           35
# (image, showing)       33
# (npm, run)             32
# (social, medium)       31
# (td, aligncentera)     30
# (aligncenter, img)     28
# (open, source)         28
# (npm, install)         28
# (navigation, bar)      25
# (front, line)          25
# (page, user)           24
# (line, worker)         24
# (section, help)        23
# (machine, learning)    23
# dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
top_20_bigrams.sort_values().plot.barh(color='pink', width=.9, figsize=(10, 6))

plt.title('20 Most frequently occuring bigrams')
plt.ylabel('Bigram')
plt.xlabel('# Occurances')

# make the labels pretty
ticks, _ = plt.yticks()
labels = top_20_bigrams.reset_index()['index'].apply(lambda t: t[0] + ' ' + t[1])
_ = plt.yticks(ticks, labels)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from pprint import pprint

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.metrics import classification_report


tfidf = TfidfVectorizer()
X = tfidf.fit_transform(df.stemmed)
y = df.language

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=.2)

train = pd.DataFrame(dict(actual=y_train))
test = pd.DataFrame(dict(actual=y_test))

lm = LogisticRegression().fit(X_train, y_train)

train['predicted'] = lm.predict(X_train)
test['predicted'] = lm.predict(X_test)

# %%
print('Accuracy: {:.2%}'.format(accuracy_score(train.actual, train.predicted)))
print('---')
print('Confusion Matrix')
print(pd.crosstab(train.predicted, train.actual))
print('---')
print(classification_report(train.actual, train.predicted))
# Out:
# Accuracy: 73.60%
# ---
# Confusion Matrix
# actual      CSS  Dart  HTML  Java  JavaScript  Python  R  Swift  TypeScript
# predicted
# HTML          0     1    33     0           0       0  1      0           0
# Java          0     0     0     7           0       0  0      0           0
# JavaScript    7     9     1     7          46       0  2      7          10
# Python        1     0     0     0           0      31  1      0           0
# R             0     0     0     0           0       0  6      0           0
# TypeScript    0     0     0     0           0       0  0      0           8
# ---
#               precision    recall  f1-score   support
#
#          CSS       0.00      0.00      0.00         8
#         Dart       0.00      0.00      0.00        10
#         HTML       0.94      0.97      0.96        34
#         Java       1.00      0.50      0.67        14
#   JavaScript       0.52      1.00      0.68        46
#       Python       0.94      1.00      0.97        31
#            R       1.00      0.60      0.75        10
#        Swift       0.00      0.00      0.00         7
#   TypeScript       1.00      0.44      0.62        18
#
#     accuracy                           0.74       178
#    macro avg       0.60      0.50      0.52       178
# weighted avg       0.71      0.74      0.68       178
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print('Accuracy: {:.2%}'.format(accuracy_score(test.actual, test.predicted)))
print('---')
print('Confusion Matrix')
print(pd.crosstab(test.predicted, test.actual))
print('---')
print(classification_report(test.actual, test.predicted))
# Out:
# Accuracy: 31.11%
# ---
# Confusion Matrix
# actual      CSS  Dart  HTML  Java  JavaScript  Python  R  Swift  TypeScript
# predicted
# HTML          0     0     2     0           1       0  1      0           0
# JavaScript    1     2     6     4          10       7  2      1           4
# Python        1     0     0     0           1       1  0      0           0
# TypeScript    0     0     0     0           0       0  0      0           1
# ---
#               precision    recall  f1-score   support
#
#          CSS       0.00      0.00      0.00         2
#         Dart       0.00      0.00      0.00         2
#         HTML       0.50      0.25      0.33         8
#         Java       0.00      0.00      0.00         4
#   JavaScript       0.27      0.83      0.41        12
#       Python       0.33      0.12      0.18         8
#            R       0.00      0.00      0.00         3
#        Swift       0.00      0.00      0.00         1
#   TypeScript       1.00      0.20      0.33         5
#
#     accuracy                           0.31        45
#    macro avg       0.23      0.16      0.14        45
# weighted avg       0.33      0.31      0.24        45
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
tfidf = TfidfVectorizer()
X = tfidf.fit_transform(df.stemmed)
y = df.language

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=13)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .25, random_state=13)

tree = DecisionTreeClassifier(max_depth=15, random_state=13)
tree.fit(X_train, y_train)

print(f'Accuracy Score: {tree.score(X_test, y_test) * 100:.2f}%')
# Out:
# Accuracy Score: 35.56%

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.metrics import classification_report
from sklearn import tree

# %%
cv = CountVectorizer()
X = cv.fit_transform(df.stemmed)
y = df.language

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=13)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .25, random_state=13)

tree = DecisionTreeClassifier(max_depth=9, random_state=13)
tree.fit(X_train, y_train)

print(f'Accuracy Score: {tree.score(X_test, y_test) * 100:.2f}%')
# Out:
# Accuracy Score: 35.56%

# %%
cv = CountVectorizer(ngram_range=(2, 2))
X = cv.fit_transform(df.stemmed)
y = df.language

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=13)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .25, random_state=13)

tree = DecisionTreeClassifier(max_depth=7, random_state=13)
tree.fit(X_train, y_train)

print(f'Accuracy Score: {tree.score(X_train, y_train) * 100:.2f}%')
# Out:
# Accuracy Score: 45.86%

# %%
cv = CountVectorizer(ngram_range=(4, 4))
X = cv.fit_transform(df.stemmed)
y = df.language

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=13)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .25, random_state=13)

tree = DecisionTreeClassifier(max_depth=7, random_state=13)
tree.fit(X_train, y_train)

print(f'Accuracy Score: {tree.score(X_val, y_val) * 100:.2f}%')
# Out:
# Accuracy Score: 42.22%

# %%
all_words = re.sub(r'[^\w\s]', '', (' '.join(df.lemmatized))).split()
all_freq = pd.Series(all_words).value_counts()
    
mask = all_freq > 1
all_not_unique = list(all_freq[mask].index)

# %%
bigrams = df.apply(lambda x : list(nltk.ngrams(x, 2)))

# %%
bigrams
# Out:
#                                                   repo              language  \
# 0    (dreamingechoes/awesome-mental-health, Flaque/...    (HTML, TypeScript)
# 1                 (Flaque/quirk, sepandhaghighi/nafas)  (TypeScript, Python)
# 2       (sepandhaghighi/nafas, youarerad/youareradweb)  (Python, TypeScript)
# 3          (youarerad/youareradweb, chroline/well_app)    (TypeScript, Dart)
# 4    (chroline/well_app, BekahHW/postpartum-wellnes...    (Dart, TypeScript)
# ..                                                 ...                   ...
# 217  (Teesha-11-Jain/Officebot, EdwardRees/Self-Car...  (Python, TypeScript)
# 218  (EdwardRees/Self-Care-Project, sumantchirde/Me...  (TypeScript, Python)
# 219  (sumantchirde/Mental-Health-NLP-project, Levod...  (Python, JavaScript)
# 220         (Levodex/RipplerPy, acfromspace/soulstone)    (JavaScript, HTML)
# 221  (acfromspace/soulstone, brunomontezano/gender-...             (HTML, R)
#
#                                        readme_contents  \
# 0    (\n<p align="center"><img src="./media/logo.pn...
# 1    (🚧🚧🚧\n\n**Quirk is no longer being maintained....
# 2    (<div align="center">\n<img src="https://githu...
# 3    (<div align="center"><img src="https://res.clo...
# 4    (![The Well App](thumbnail.png)\n\n<div align=...
# ..                                                 ...
# 217  (-> Following is just a prototype!\n# Problem ...
# 218  (# Self Care Project\n\nWhat used to be a Ment...
# 219  (#  Mental health assessment by NLP and ML usi...
# 220  (## About\n* \n* (Read github/bitbucket descri...
# 221  (<!-- HEADING -->\n\n<h1 align="center">soulst...
#
#                                                stemmed  \
# 0    (aboutsparkl curat list awesom articl websit r...
# 1    (quirk longer maintainedquirk start littl thin...
# 2    (nafa &#9; tabl content overview instal usag i...
# 3    (welcom rise disord ' websit repow nonprofit c...
# 4    (well appthumbnailpng quick link well app avai...
# ..                                                 ...
# 217  (follow prototyp problem statementto solv issu...
# 218  (self care projectwhat use mental health proje...
# 219  (mental health assess nlp ml use tensorflownow...
# 220  (read githubbitbucket descript copyright notic...
# 221  (soulstoneperson reflect thought one ' selfswe...
#
#                                             lemmatized   total_words  \
# 0    (aboutsparkles curated list awesome article we...  (1140, 1061)
# 1    (quirk longer maintainedquirk started little t...   (1061, 351)
# 2    (nafas &#9; table content overview installatio...     (351, 83)
# 3    (welcome rise disorder ' website repowe nonpro...     (83, 320)
# 4    (well appthumbnailpng quick link well app avai...    (320, 352)
# ..                                                 ...           ...
# 217  (following prototype problem statementto solve...     (600, 49)
# 218  (self care projectwhat used mental health proj...      (49, 88)
# 219  (mental health assessment nlp ml using tensorf...     (88, 155)
# 220  (read githubbitbucket description copyright no...     (155, 15)
# 221  (soulstonepersonal reflection thought one ' se...     (15, 101)
#
#                     count_bin
# 0    (high_count, high_count)
# 1    (high_count, high_count)
# 2     (high_count, med_count)
# 3     (med_count, high_count)
# 4    (high_count, high_count)
# ..                        ...
# 217   (high_count, low_count)
# 218    (low_count, med_count)
# 219    (med_count, med_count)
# 220    (med_count, low_count)
# 221    (low_count, med_count)
#
# [222 rows x 7 columns]

# %%
def make_word_list(df):
    """ creates a list of every not unique word in dataframe"""
    all_words = re.sub(r'[^\w\s]', '', (' '.join(df.lemmatized))).split()
    all_freq = pd.Series(all_words).value_counts()
    
    mask = all_freq > 1
    all_not_unique = list(all_freq[mask].index)
    
    return all_not_unique

def finding_non_single_words(x):
    """finds all words in column that appear in df more than one time
    will be used to make a column that counts words that appear more than once"""
    all_not_unique = make_word_list(df)
    l = []
    for w in x:
        if w in all_not_unique:
            l.append(w)
    return l


def feature_engineering(df):
    """creates calculated columns for df subsetted by type of column"""
    
    #list making features 
    df['word_list'] = df.lemmatized.apply(lambda x: re.sub(r'[^\w\s]', '', x).split())
    df['unique_words'] = df.word_list.apply(lambda x: pd.Series(x).unique())
    df['non_single_words'] = df.word_list.apply(lambda x: finding_non_single_words(x))

    # counting
    df['word_count_simple'] = df.lemmatized.str.count(" ") + 1
    df['word_count'] = df.word_list.apply(lambda x: len(x))
    df['unique_count'] = df.unique_words.apply(lambda x: len(x))
    df['non_single_count'] = df.non_single_words.apply(lambda x: len(x))

    # calculating
    df['percent_unique'] = (df.unique_count / df.word_count)
    df['percent_repeat'] = (1 - df.unique_count / df.word_count)
    df['percent_one_word'] = df.word_list.apply(lambda x: (pd.Series(x).value_counts() == 1).mean())
    df['percent_non_single'] = (df.non_single_count / df.word_count)

    return df

# new dataframes

def language_series(df):
    """makes df with words and frequency of words for each programming language"""

    all_words = (' '.join(df.lemmatized))
    all_words = re.sub(r'[^\w\s]', '', all_words).split()
    all_freq = pd.Series(all_words).value_counts()

    php_words = (' '.join(df[df.language == 'PHP'].lemmatized))
    php_words = re.sub(r'[^\w\s]', '', php_words).split()
    php_freq = pd.Series(php_words).value_counts()

    python_words = (' '.join(df[df.language == 'Python'].lemmatized))
    python_words = re.sub(r'[^\w\s]', '', python_words).split()
    python_freq = pd.Series(python_words).value_counts()

    java_words = (' '.join(df[df.language == 'Java'].lemmatized))
    java_words = re.sub(r'[^\w\s]', '', java_words).split()
    java_freq = pd.Series(java_words).value_counts()

    js_words = (' '.join(df[df.language == 'JavaScript'].lemmatized))
    js_words = re.sub(r'[^\w\s]', '', js_words).split()
    js_freq = pd.Series(js_words).value_counts()

    freq_df = pd.DataFrame({'all': all_freq,
                       'php': php_freq,
                       'python': python_freq,
                       'java': java_freq,
                       'java_script': js_freq
                        })
    freq_df = freq_df.fillna(0)
    freq_df = freq_df.astype(int)

    return freq_df

def make_language_df(df=df):
    """creates a data frame of words in rows"""
    freq_df = language_series(df)
    
    freq_list = freq_df['all'].sort_values(ascending = False).head(15).index
    
    df_js = df[0:200]
    df_python = df[200:400]
    df_java = df[400:600]
    df_php= df[600:800]
    
    all_list = []
    js_list = []
    python_list = []
    php_list = []
    java_list = []
    
    for i in freq_list:
        v = len(pd.DataFrame({'loc_index' :df[df.lemmatized.apply(lambda x: len(re.findall(i, x))) > 0].index}))
        all_list.append(v)
    
        js = len(pd.DataFrame({'loc_index' :df_js[df_js.lemmatized.apply(lambda x: len(re.findall(i, x))) > 0].index}))
        js_list.append(js)
   
        py = len(pd.DataFrame({'loc_index' :df_python[df_python.lemmatized.apply(lambda x: len(re.findall(i, x))) > 0].index}))
        python_list.append(py)
    
        php = len(pd.DataFrame({'loc_index' :df_php[df_php.lemmatized.apply(lambda x: len(re.findall(i, x))) > 0].index}))
        php_list.append(php)
    
        jv = len(pd.DataFrame({'loc_index' :df_java[df_java.lemmatized.apply(lambda x: len(re.findall(i, x))) > 0].index}))
        java_list.append(jv)
        
    language_df = pd.DataFrame({'word': freq_list,
                         'all_languages': all_list,
                        'javascript': js_list,
                         'python': python_list,
                        'php': php_list,
                            'java': java_list
                        })
        
    return language_df
